# %%
import sys
import os


# Basic
import numpy as np
import numpy as np

def dummy_npwarn_decorator_factory():
  def npwarn_decorator(x):
    return x
  return npwarn_decorator
np._no_nep50_warning = getattr(np, '_no_nep50_warning', dummy_npwarn_decorator_factory)
import matplotlib.pyplot as plt

# Dataset
from keras.datasets import fashion_mnist

# Evaluation
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

# Your SOM model
from som import SOM
# Out:
# 2025-04-28 17:36:49.633771: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-28 17:36:49.686047: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-28 17:36:49.735939: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745876209.823688   17951 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745876209.859001   17951 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745876209.978574   17951 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745876209.978620   17951 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745876209.978624   17951 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745876209.978626   17951 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-28 17:36:49.993642: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load data
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Flatten images from (28,28) to (784,)
X_train = X_train.reshape(-1, 28*28).astype(np.float32) / 255.0
X_test = X_test.reshape(-1, 28*28).astype(np.float32) / 255.0

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (60000, 784)
# Test shape: (10000, 784)

# %%
# Downsizing

X_train = X_train[:10000]
X_test = X_test[:1000]

# %%
import matplotlib.pyplot as plt
import numpy as np

num_samples = 25  # you can change this
grid_size = int(num_samples ** 0.5)

# randomly select 25 samples from X_train
indices = np.random.choice(len(X_train), size=num_samples, replace=False)
selected_samples = X_train[indices]

fig, axes = plt.subplots(grid_size, grid_size, figsize=(10, 10))
axes = axes.flatten()

for ax, neuron_weights in zip(axes, selected_samples.reshape(-1, 784)):
    img = neuron_weights.reshape(28, 28)
    ax.imshow(img, cmap='gray')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Initialize SOM
som = SOM(
    lattice_rows=5,
    lattice_columns=5,
    initial_learning_rate=1,
    neighbourhood_radius=3,
    max_iters=1000,
    learning_rate_type="exponential",
    random_state=42,
    verbose=True,
    use_tqdm=True
)

# Fit SOM
som.fit(X_train)
# Out:
#   2%|████▊                                                                                                                                                                                                                                                                                                        | 16/1000 [00:12<13:01,  1.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#       2 som = SOM(
#       3     lattice_rows=5,
#       4     lattice_columns=5,
#    (...)     11     use_tqdm=True
#      12 )
#      14 # Fit SOM
# ---> 15 som.fit(X_train)
#
# File ~/Projects/scikit-learn-som/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Projects/scikit-learn-som/src/som/som.py:161, in SOM.fit(self, X, y)
#     158 lattice_weights += learning_rate * neighborhood_influence[..., np.newaxis] * error
#     160 flat_weights = lattice_weights.reshape(-1, n_features)
# --> 161 dists = self._compute_distance(X[:, np.newaxis, :], flat_weights[np.newaxis, :, :])
#     163 best_indices = np.argmin(dists, axis=1)
#     164 rows = best_indices // self.lattice_columns
#
# File ~/Projects/scikit-learn-som/src/som/som.py:99, in SOM._compute_distance(self, A, B)
#      97 def _compute_distance(self, A, B):
#      98     if self.distance_metric == "euclidean":
# ---> 99         return np.sum((A - B) ** 2, axis=-1)
#     100     elif self.distance_metric == "manhattan":
#     101         return np.sum(np.abs(A - B), axis=-1)
#
# File ~/Projects/scikit-learn-som/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File ~/Projects/scikit-learn-som/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
som.plot_inertia()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 som.plot_inertia()
#
# File ~/Projects/scikit-learn-som/src/som/som.py:229, in SOM.plot_inertia(self)
#     227 def plot_inertia(self):
#     228     """Plot Inertia over Training Epochs."""
# --> 229     check_is_fitted(self, attributes=["inertia_history_"])
#     230     import matplotlib.pyplot as plt
#     232     plt.figure(figsize=(8, 4))
#
# File ~/Projects/scikit-learn-som/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1757, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754     return
#    1756 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1757     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This SOM instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
som.plot_clusters(X_train, y_train)
som.plot_clusters(X_test, y_test)

# %%
pred.plot_umatrix()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 5, figsize=(10, 10))
axes = axes.flatten()

for ax, neuron_weights in zip(axes, som.weights_.reshape(-1, 784)):
    img = neuron_weights.reshape(28, 28)
    ax.imshow(img, cmap='gray')
    ax.axis('off')

plt.tight_layout()
plt.show()
